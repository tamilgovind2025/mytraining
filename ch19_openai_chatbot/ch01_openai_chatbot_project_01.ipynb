# %%
pip install streamlit pypdf2 langchain faiss-cpu
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ------------------------------ ------- 41.0/50.7 kB 960.0 kB/s eta 0:00:01
#      -------------------------------------- 50.7/50.7 kB 642.6 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.1/8.1 MB 5.1 MB/s eta 0:00:02
#    - -------------------------------------- 0.3/8.1 MB 3.8 MB/s eta 0:00:03
#    --- ------------------------------------ 0.7/8.1 MB 5.4 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.2/8.1 MB 6.9 MB/s eta 0:00:02
#    --------- ------------------------------ 2.0/8.1 MB 9.8 MB/s eta 0:00:01
#    -------------------- ------------------- 4.1/8.1 MB 16.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.7/8.1 MB 19.3 MB/s eta 0:00:01
# ...
