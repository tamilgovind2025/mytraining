# %% [markdown]
# # object detection

# %% [raw]
# # 1. simple template matching
# 2. corner detection
# 3. edge detection
# 4. grid detection (real time used )
# 5. contour detection (detect foreground and background )
# 6. feature matching (more advanced method if target image not show exatcly it will find )
# 7. watershed algorithm (fg and bg manually choose segment of image )
# 8. facial and eye detection :
#     haar cascade to detect face
#     note. not facial detection for that we have to use deep learning

# %% [markdown]
# # template matching

# %%
import cv2 
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
full=cv2.imread("../DATA/govind.png")
full=cv2.cvtColor(full,cv2.COLOR_BGR2RGB)
plt.imshow(full)

# %%
face=cv2.imread("../DATA/face.png")
face=cv2.cvtColor(face,cv2.COLOR_BGR2RGB)
plt.imshow(face)

# %%
full.shape
# Out:
# (668, 955, 3)

# %%
face.shape
# Out:
# (507, 497, 3)

# %%
sum([1,2,3])
# Out:
# 6

# %%
mystring="sum"
mystring([1,2,3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 mystring="sum"
# ----> 2 mystring([1,2,3])
#
# TypeError: 'str' object is not callable

# %%
myfunc=eval(mystring)
myfunc([1,2,3,4])
# Out:
# 10

# %%
myfunc=eval("sum")
myfunc([1,2,3,4])
# Out:
# 10

# %%
# All the 6 methods for comparison in a list
# Note how we are using strings, later on we'll use the eval() function to convert to function
methods = ['cv2.TM_CCOEFF', 'cv2.TM_CCOEFF_NORMED', 'cv2.TM_CCORR','cv2.TM_CCORR_NORMED', 'cv2.TM_SQDIFF', 'cv2.TM_SQDIFF_NORMED']

# %%
for m in methods:
    full_copy=full.copy()
    method=eval(m)
    
    #template matching 
    res=cv2.matchTemplate(full_copy,face,method)
    
    min_val,max_val,min_loc,max_loc=cv2.minMaxLoc(res)
    
    if method in [cv2.TM_SQDIFF,cv2.TM_SQDIFF_NORMED]:
        top_left=min_loc
        
    else:
        top_left=max_loc
        
    height,width,channels=face.shape
    
    bottom_right=(top_left[0]+width,top_left[1]+height)
    
    cv2.rectangle(full_copy,top_left,bottom_right,(0,0,255),10)
    
    #plot to show images 
    plt.subplot(121)
    plt.imshow(res)
    plt.title("HEATMAP OF TEMPLATE")
    
    plt.subplot(122)
    plt.imshow(full_copy)
    plt.title("DETECTION OF TEMPLATE")
    
    plt.suptitle(m)
    
    plt.show()  #to avoid collapse
