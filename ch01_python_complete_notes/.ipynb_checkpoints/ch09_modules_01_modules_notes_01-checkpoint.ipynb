# %%
"""
sys 
datetime 
math

"""
# Out:
# '\nsys \ndatetime \nmath\n\n'

# %%
import sys 

sys.stderr.write("this sys err print")
sys.stderr.flush()
sys.stdout.write("this is std out print")
# Out:
# this sys err print
# this is std out print
# 21

# %%
#save in local file and execute in command line 
#save file as sys.py 

#> pyhton sys.py " look at that "

if len(sys.argv)>1:
    print(sys.argv[1])
    
#> python sys.py "look at that "
print(float(sys.argv)+5)
# Out:
# -f
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 10
#       7     print(sys.argv[1])
#       9 #> python sys.py "look at that "
# ---> 10 print(float(sys.argv)+5)
#
# TypeError: float() argument must be a string or a real number, not 'list'

# %%
print(sys.platform)
# Out:
# win32

# %%
print(sys.version)
# Out:
# 3.11.5 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:26:23) [MSC v.1916 64 bit (AMD64)]

# %%
sys.exit(1)
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1

# %%
# %tb
# Out:
# ---------------------------------------------------------------------------
# SystemExit                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 sys.exit(1)
#
# SystemExit: 1

# %%
print(sys.path)
# Out:
# ['C:\\Users\\admin\\Documents\\govindarasan_ws\\mytrain\\mytraining\\ch01_python_complete_notes', 'C:\\ProgramData\\anaconda3\\python311.zip', 'C:\\ProgramData\\anaconda3\\DLLs', 'C:\\ProgramData\\anaconda3\\Lib', 'C:\\ProgramData\\anaconda3', '', 'C:\\Users\\admin\\AppData\\Roaming\\Python\\Python311\\site-packages', 'C:\\ProgramData\\anaconda3\\Lib\\site-packages', 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\win32', 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\win32\\lib', 'C:\\ProgramData\\anaconda3\\Lib\\site-packages\\Pythonwin']

# %%
print(sys.modules)
# Out:
# {'sys': <module 'sys' (built-in)>, 'builtins': <module 'builtins' (built-in)>, '_frozen_importlib': <module '_frozen_importlib' (frozen)>, '_imp': <module '_imp' (built-in)>, '_thread': <module '_thread' (built-in)>, '_warnings': <module '_warnings' (built-in)>, '_weakref': <module '_weakref' (built-in)>, 'winreg': <module 'winreg' (built-in)>, '_io': <module '_io' (built-in)>, 'marshal': <module 'marshal' (built-in)>, 'nt': <module 'nt' (built-in)>, '_frozen_importlib_external': <module '_frozen_importlib_external' (frozen)>, 'time': <module 'time' (built-in)>, 'zipimport': <module 'zipimport' (frozen)>, '_codecs': <module '_codecs' (built-in)>, 'codecs': <module 'codecs' (frozen)>, 'encodings.aliases': <module 'encodings.aliases' from 'C:\\ProgramData\\anaconda3\\Lib\\encodings\\aliases.py'>, 'encodings': <module 'encodings' from 'C:\\ProgramData\\anaconda3\\Lib\\encodings\\__init__.py'>, 'encodings.utf_8': <module 'encodings.utf_8' from 'C:\\ProgramData\\anaconda3\\Lib\\encodings\
# ...

# %%
arguments = ["my_script.py", "arg1", "arg2"]  # Script name and arguments

# Access arguments
script_name = arguments[0]
first_arg = arguments[1]

print(f"Script name: {script_name}")
print(f"First argument: {first_arg}")
# Out:
# Script name: my_script.py
# First argument: arg1

# %%
print(sys.implementation.name)
# Out:
# cpython

# %% [raw]
# Accessing Frame Objects:
# You can access the current execution frame and the call stack using sys._getframe(). This can be useful for debugging purposes, but it's generally not recommended for regular use.

# %%
frame = sys._getframe()
print("Current function name:", frame.f_code.co_name)
# Out:
# Current function name: <module>

# %% [raw]
# Clearing Imported Modules:
# You can clear all imported modules from memory using sys.modules.clear(). This can be useful in certain situations, such as in long-running processes to free up memory.

# %%
import sys

sys.modules.clear()

# %% [markdown]
# Accessing the Current Thread's Recursion Depth:
# You can access the current thread's recursion depth using the sys.getrecursionlimit() function. This can be useful for understanding the current state of the recursion limit.

# %% [raw]
# Accessing the Python Compiler Flags:
# You can access the compiler flags used to compile the current Python interpreter using the sys.flags attribute. This can be useful for understanding the compilation options and behavior of the interpreter.

# %%
import sys

print("Python compiler flags:", sys.flags)
